# %% [markdown]
# # Import Libraries

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # User Agent

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %% [markdown]
# # Scraping

# %%
def scrapePage(page):
    review_stars = []
    reviews = []
    #for each card in the page
    page = BeautifulSoup(page.text, "html.parser")
    for card in page.find_all("div",attrs={'data-hook':'review'},class_='a-section review aok-relative'):
        #find star ratings
        stari = card.find("i",attrs={'data-hook':'review-star-rating'})
        stars = stari.find("span",class_='a-icon-alt')
        review_stars.append(int(stars.text[0]))
        review = card.find("span",attrs={'data-hook':'review-body','class':'a-size-base review-text review-text-content'})
        # review = review.find("span")
        reviews.append(review.text.strip())
    return reviews, review_stars

# %%
from tqdm.notebook import tqdm_notebook

# reviews=[]
# stars=[]
LIMIT=100

url_link='https://www.amazon.in/Echo-Dot-3rd-Gen/product-reviews/B07PFFMP9P/ref=cm_cr_arp_d_viewopt_sr?ie=UTF8&reviewerType=all_reviews&pageNumber=1&filterByStar=five_star'
i=1
for i in tqdm_notebook(range(1,LIMIT),desc='Scraping:'):
  page = requests.get(url_link + str(i), headers=HEADERS)
  i+=1
  reviewsp, starsp = scrapePage(page)
  reviews.extend(reviewsp)
  stars.extend(starsp)
print("# PAGE STATUS 200: ",i,"/",LIMIT)
# Out:
# Scraping::   0%|          | 0/99 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py:488, in PyOpenSSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     487 try:
# --> 488     cnx.do_handshake()
#     489 except OpenSSL.SSL.WantReadError:
#
# File ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py:1991, in Connection.do_handshake(self)
#    1990 result = _lib.SSL_do_handshake(self._ssl)
# -> 1991 self._raise_ssl_error(self._ssl, result)
#
# File ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py:1692, in Connection._raise_ssl_error(self, ssl, result)
#    1691     if errno != 0:
# -> 1692         raise SysCallError(errno, errorcode.get(errno))
#    1693 raise SysCallError(-1, "Unexpected EOF")
#
# ...

# %%
reviews
# Out:
# ['I have not integrated it with anything. I just use it for listening to music or find out quick information from net. My daughter uses it for alarm etc. We find it very convenient. I love the feature of voice based command as 8 can just listen to anything by asking Alexa, while i am working at home.',
#  'I had a mini for some time but it just wouldn’t recognise my mother’s commands. I bought this dot as i got it for a good price, expecting similar experience but i was taken aback by how well it recognised commands even with a thick accent all the while playing music at a high volume. It executes smart home tasks remarkably well and better than nest mini.All things considered it’s a great accessory to have for your smart home ecosystem.',
#  'In this product please provide a battery with 10 hours play back continuously.',
#  'Device not control Samsung smart tv',
#  'Good to have one especially for small kids .',
#  "It's value for money",
# ...

# %%
len(stars)
# Out:
# 310

# %% [markdown]
# # Saving in .csv

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['reviews']=reviews
df['stars']=stars

# %%
df.head()
# Out:
#                                              reviews  stars
# 0  I have not integrated it with anything. I just...      4
# 1  I had a mini for some time but it just wouldn’...      4
# 2  In this product please provide a battery with ...      4
# 3                Device not control Samsung smart tv      4
# 4       Good to have one especially for small kids .      4

# %%
df.stars.unique()
# Out:
# array([4])

# %%
df.shape
# Out:
# (310, 2)

# %%
df.to_csv('./Datasets/amazon_reviews.csv',index=False)
